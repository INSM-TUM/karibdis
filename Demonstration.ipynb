# %% [markdown]
# #### <font color='#0000DD'><b> Welcome to the prototype demonstration for the paper *KRAFT -- A Knowledge-Graph-Based Resource Allocation Framework*
# <font color='#0000DD'><b> This Jupyter Notebook walks you through the features of the prototype and framework. Marked in blue is contextual information and instructions.

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rdflib import Graph, Literal, RDF, URIRef, Namespace
from urllib.parse import quote, unquote
import pandas as pd
from datetime import timedelta

# %%
import sys  
import os
root = os.path.abspath('')
sys.path.insert(1, root + '/Business Process Optimization Competition 2023')
from simulator import Simulator
from problems import MinedProblem
sys.path.insert(1, root + '/src')
from KGPlanner import KGPlanner, Mode
from ProcessKnowledgeGraph import ProcessKnowledgeGraph
from SHACLAllocator import SHACLAllocator 
from SimulatorForDemonstration import SimulatorForDemonstration
from utils import *

# %% [markdown]
# # Mining Resource Expertise
# <font color='#0000DD'><b>The following demonstrates how process mining techniques can be utilized to extract knowledge about resources, in this case expertise for specific loan goals derived from the RBI 1.2 "Case Types" from Pika et al., "Mining Resource Profiles from Event Logs" (2017).
# First, the BPIC log is read from file and the respective metrics (cases completed per resource in total and further divided per loan goal) are calculated.
# Then, expertise for specific loan goals is derived via a threshold from the RBI.

# %%
import pandas as pd
import numpy as np

# %%
log = pd.read_csv('./BPI Challenge 2017 - clean.csv')
min_date = log['Start Timestamp'].min()
max_date = log['Complete Timestamp'].max()
total_cases_per_resource = log.groupby(['Resource']).agg({'Case ID' : pd.Series.nunique})['Case ID']
cases_per_resource_per_loan_goal = log.groupby(['LoanGoal', 'Resource']).agg({'Case ID' : pd.Series.nunique}).unstack()['Case ID']
cases_per_resource_per_loan_goal_fraction = cases_per_resource_per_loan_goal.div(total_cases_per_resource.transpose()).fillna(0) # The RBI 1.2
experts = cases_per_resource_per_loan_goal_fraction > 0.35

# %% [markdown]
# <font color='#0000DD'><b> To translate this knowledge to graph, nodes for the resources and loan goals as well as appropriate `expertOn` edges are created:

# %%
helper_graph = ProcessKnowledgeGraph()
for loan_goal in experts.index:
    helper_graph.add_entity('LoanGoal', loan_goal)
    for resource in experts.columns:
        if experts.loc[loan_goal][resource]:
            helper_graph.add_entity('resource', resource)
            helper_graph.add_from_strings('resource:'+resource, 'expertOn', 'LoanGoal:'+loan_goal)

# %% [markdown]
# <font color='#0000DD'><b> We further determine seniority of the resources based on the number of case completions

# %%
seniorities = total_cases_per_resource.apply(lambda cpr : 'High' if cpr > 1500 else ('Medium' if cpr > 300 else 'Low'))
for resource, seniority in seniorities.items():
    helper_graph.add_entity('resource', resource) # Redundant for resources that are not experts on anything; will not produce duplicates
    helper_graph.add_entity('Seniority', seniority)
    helper_graph.add_from_strings('resource:'+resource, 'Seniority', 'Seniority:'+seniority)

# %% [markdown]
# <font color='#0000DD'><b>  You can have a look at the generated graph as follows. Note that you can put this viewer into fullscreen mode, and you can explore a node's neighbourhood by selecting a node and opening the sidebar.

# %%
draw_graph(helper_graph)
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %% [markdown]
# <font color='#0000DD'><b> Now write the knowledge to file for later use:

# %%
helper_graph.serialize(destination='./src/extension_knowledge/expertise_instances.ttl')
# Out:
# <Graph identifier=Nf956ac6dc96a446087429e9eabaca510 (<class 'ProcessKnowledgeGraph.ProcessKnowledgeGraph'>)>

# %% [markdown]
# # Example Simulation
# <font color='#0000DD'><b>Execute the following three steps to run the example simulation. Don't rerun single steps.

# %% [markdown]
# ### Planner & Allocator Setup
# <font color='#0000DD'><b>The planner is the interface to the simulation frame, implementing a function to assign a set of open tasks.
# The allocation actually manages the reasoning based on the encoded ontology and rules. In this example setup, we load additional knowledge as described in the paper's example use case.
# Note that we reuse the knowledge earlier derived from Process Mining by loading the respective file.

# %%
planner = KGPlanner()
planner.allocator.load_extension(ontology_ext='./src/extension_knowledge/extension_ontology.ttl')
planner.allocator.load_extension(rules_ext='./src/extension_knowledge/sepOfConcerns_rules.ttl')
planner.allocator.load_extension(rules_ext='./src/extension_knowledge/riskAndSeniority_rules.ttl', instance_ext='./src/extension_knowledge/riskAndSeniority_instances.ttl')
planner.allocator.load_extension(rules_ext='./src/extension_knowledge/expertise_rules.ttl', instance_ext='./src/extension_knowledge/expertise_instances.ttl')

# %% [markdown]
# <font color='#0000DD'><b> At this point, and at any point when the simulation is paused, it is possible to manually add further knowledge.
# For example, let's manually define some expertises that have not been discovered by the process mining techniques:

# %%
planner.graph.add_from_strings('resource:User_24', 'expertOn', 'LoanGoal:Remaining debt home')
planner.graph.add_from_strings('resource:User_99', 'expertOn', 'LoanGoal:Boat')
planner.graph.add_from_strings('resource:User_123', 'expertOn', 'LoanGoal:Extra spending limit')
planner.graph.add_from_strings('resource:User_56', 'expertOn', 'LoanGoal:Home improvement')

# %% [markdown]
# ### Simulation Frame Setup
# <font color='#0000DD'><b>The simulation frame and simulated process are taken from the BPOC 2023. We adapt the simulation numbers as to allow for more interesting allocation situations.

# %%
simulator = SimulatorForDemonstration(planner=planner, instance_file='./Business Process Optimization Competition 2023/BPI Challenge 2017 - instance 2.pickle')
problem = simulator.problem
# Increase Arrival Rate so also more resources are provided
problem.interarrival_time._scale *= 0.5
# Increase likelihood for assessing fraud, so separation of concerns actually triggers
problem.next_task_distribution['W_Validate application'] = list(map(lambda x : (x[0] * 0.8 + (0.2 if (x[1] == 'W_Assess potential fraud') else 0), x[1]), problem.next_task_distribution['W_Validate application']))

# %% [markdown]
# ### Run the Simulation

# %% [markdown]
# <font color='#0000DD'><b>First, let's run just run the initial first task assignment of the simulation. The console logs show current allocation context (case, task, and activity as well as available and pool-allowed resources), the decision made by the system and the respective reasoning.

# %%
simulator.run(0)
# Out:
# 0 case-0 task-0: W_Complete application
# Resources Available: {'User_70', 'User_85', 'User_146', 'User_47', 'User_140'}
# Resources in Pool: {'User_47', 'User_70', 'User_85'}
# Assigning: User_70 to task-0 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
# User_70 is now an expert on application type New credit
# (0.0,
#  'COMPLETED: you completed 0 hours of simulated customer cases. 1 cases started. 0 cases run to completion.')

# %% [markdown]
# <font color='#0000DD'><b>We can now investigate the current state of the allocation knowledge graph after one allocation decision.
# To ensure that we only see the resources currently present, we filter accordingly.
# This is a nice illustration of the relevant entities for one single decision (although some background knowledge entities are visible as well as they are already loaded).
# Note that entities are color-coded by their type.

# %%
draw_graph(planner.graph.subgraph_available_resources())
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %% [markdown]
# <font color='#0000DD'><b> Let's resume the simulation to run 1 more hour of simulation time. This will take some (real) time. However, the simulation can be paused at any moment using Jupyter's interrupt function (the interrupt button or pressing `i` twice while having the respective cell selected.)

# %%
simulator.run(1)
# Out:
# 0.09008078297095312 case-0 task-2: W_Complete application
# Resources Available: {'User_70', 'User_85', 'User_146', 'User_47', 'User_140'}
# Resources in Pool: {'User_47', 'User_70', 'User_85'}
# Assigning: User_70 to task-2 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.17995947185881933 case-0 task-3: W_Call after offers
# Resources Available: {'User_70', 'User_85', 'User_146', 'User_47', 'User_140'}
# Resources in Pool: {'User_47', 'User_70', 'User_85'}
# Assigning: User_70 to task-3 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 0.29207814462803483 case-0 task-4: W_Call after offers
# Resources Available: {'User_70', 'User_85', 'User_146', 'User_47', 'User_140'}
# Resources in Pool: {'User_47', 'User_70', 'User_85'}
# Assigning: User_70 to task-4 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 0.37575330704149273 case-1 task-1: W_Complete application
# Resources Available: {'User_70', 'User_85', 'User_146', 'User_47', 'User_140'}
# Resources in Pool: {'User_47', 'User_70', 'User_85'}
# Assigning: User_70 to task-1 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.4297812831403975 case-2 task-5: W_Complete application
# Resources Available: {'User_47', 'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85', 'User_47'}
# Assigning: User_85 to task-5 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.44057647852264037 case-3 task-6: W_Complete application
# Resources Available: {'User_47', 'User_146', 'User_140'}
# Resources in Pool: {'User_47'}
# Assigning: User_47 to task-6 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Not speficied'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.4409600619569145 case-4 task-7: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.49074693161177674 case-1 task-9: W_Complete application
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-9 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.49074693161177674 case-4 task-7: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.5238835462276481 case-2 task-10: W_Complete application
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-10 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.5238835462276481 case-4 task-7: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.5992721507096126 case-4 task-7: W_Complete application
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-7 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.5992721507096126 case-1 task-11: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.6088697232826675 case-3 task-12: W_Call after offers
# Resources Available: {'User_47', 'User_146', 'User_140'}
# Resources in Pool: {'User_47'}
# Assigning: User_47 to task-12 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Not speficied'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 0.6088697232826675 case-1 task-11: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.6188427366195677 case-2 task-13: W_Call after offers
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-13 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 0.6188427366195677 case-1 task-11: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.691665017466436 case-2 task-14: W_Call after offers
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-14 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 0.691665017466436 case-1 task-11: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.7288168662642592 case-2 task-15: W_Validate application
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-15 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Validate application'
#
#
# 0.7288168662642592 case-1 task-11: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.7332726737783899 case-4 task-16: W_Call after offers
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-16 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 0.7332726737783899 case-1 task-11: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.7517475645857266 case-5 task-8: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.7517475645857266 case-1 task-11: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.7788152020896061 case-5 task-8: W_Complete application
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-8 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.7788152020896061 case-2 task-18: W_Call incomplete files
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: {'User_146'}
# Assigning: User_146 to task-18 considering the following:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call incomplete files'
#
#
# 0.8222323014594497 case-4 task-19: W_Validate application
# Resources Available: {'User_70', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-19 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Validate application'
#
#
# 0.8356569869507302 case-4 task-20: W_Assess potential fraud
# Resources Available: {'User_70', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.8356569869507302 case-1 task-11: W_Call after offers
# Resources Available: {'User_70', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-11 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 0.8788079996276613 case-5 task-21: W_Call after offers
# Resources Available: {'User_85', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-21 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 0.9208301627903733 case-4 task-20: W_Assess potential fraud
# Resources Available: {'User_85', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-20 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Assess potential fraud'
#
#
# 0.934493678618417 case-5 task-22: W_Call after offers
# Resources Available: {'User_70', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-22 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 0.9429647805909517 case-4 task-23: W_Validate application
# Resources Available: {'User_85', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-23 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Validate application'
#
#
# 0.9778048603589838 case-6 task-17: W_Complete application
# Resources Available: {'User_70', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-17 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.9992783746695918 case-9 task-26: W_Complete application
# Resources Available: {'User_85', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-26 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.9992783746695918 case-11 task-28: W_Complete application
# Resources Available: {'User_96', 'User_99', 'User_97', 'User_140'}
# Resources in Pool: {'User_99', 'User_96', 'User_97'}
# Assigning: User_99 to task-28 considering the following:
#  	Seniority 'High' is sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.9992783746695918 case-4 task-31: W_Call incomplete files
# Resources Available: {'User_96', 'User_97', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.9992783746695918 case-5 task-30: W_Validate application
# Resources Available: {'User_96', 'User_97', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 0.9992783746695918 case-7 task-24: W_Complete application
# Resources Available: {'User_96', 'User_97', 'User_140'}
# Resources in Pool: {'User_96', 'User_97'}
# Assigning: User_96 to task-24 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 0.9992783746695918 case-10 task-27: W_Complete application
# Resources Available: {'User_97', 'User_140'}
# Resources in Pool: {'User_97'}
# Assigning: User_97 to task-27 considering the following:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 1.0845003679341687 case-12 task-29: W_Complete application
# Resources Available: {'User_70', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-29 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 1.0882699901398492 case-4 task-31: W_Call incomplete files
# Resources Available: {'User_85', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-31 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call incomplete files'
# (0.2913405759499653,
#  'COMPLETED: you completed 1.0900807829709531 hours of simulated customer cases. 14 cases started. 3 cases run to completion.')

# %% [markdown]
# <font color='#0000DD'><b> While paused, we can add more knowledge, and also change the system mode to human-in-the-loop (HITL).
# In HITL, the system prompts users for every allocation decision. We can then continue the simulation a little more in this mode.

# %%
planner.graph.add_entity('ApplicationType', 'Limit raise')
planner.graph.add_from_strings('resource:'+resource, 'expertOn', 'ApplicationType:Limit raise')
planner.mode = Mode.HUMAN_IN_THE_LOOP
simulator.run(0.1)
# Out:
# 1.1337856094570307 case-10 task-36: W_Call after offers
# Resources Available: {'User_97', 'User_140'}
# Resources in Pool: {'User_97'}
# The following resources are available:
# 0: User_97, score: 2, considering:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Call after offers'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
#  0
# Assigning: User_97 to task-36 considering the following:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.1675080425332238 case-4 task-37: W_Call incomplete files
# Resources Available: {'User_85', 'User_140'}
# Resources in Pool: {'User_85'}
# The following resources are available:
# 0: User_85, score: -1, considering:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call incomplete files'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Call incomplete files'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Assigning: User_85 to task-37 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call incomplete files'
#
#
# 1.1716983190590837 case-14 task-35: W_Complete application
# Resources Available: {'User_96', 'User_140'}
# Resources in Pool: {'User_96'}
# The following resources are available:
# 0: User_96, score: 2, considering:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Other, see explanation'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Other, see explanation'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Complete application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Assigning: User_96 to task-35 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Other, see explanation'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 1.1795967799120493 case-5 task-30: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_140, score: -inf, considering:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Validate application'
#
# 1: User_146, score: -inf, considering:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Validate application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1795967799120493 case-7 task-39: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Call after offers'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Call after offers'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1795967799120493 case-6 task-33: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Complete application'
#
# 1: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Complete application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1795967799120493 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Complete application'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Complete application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1795967799120493 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Call after offers'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Call after offers'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1795967799120493 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Complete application'
#
# 1: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Complete application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1795967799120493 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Validate application'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Validate application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1905044636735842 case-5 task-30: W_Validate application
# Resources Available: {'User_99', 'User_146', 'User_140'}
# Resources in Pool: {'User_99'}
# The following resources are available:
# 0: User_99, score: 2, considering:
#  	Seniority 'High' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource has relevant role(s) for activity 'W_Validate application'
#
# 1: User_146, score: -inf, considering:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Validate application'
#
# 2: User_140, score: -inf, considering:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Validate application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
#  0
# Assigning: User_99 to task-30 considering the following:
#  	Seniority 'High' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource has relevant role(s) for activity 'W_Validate application'
#
#
# 1.1905044636735842 case-7 task-39: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Call after offers'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Call after offers'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1905044636735842 case-6 task-33: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Complete application'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Complete application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1905044636735842 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Complete application'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Complete application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1905044636735842 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Call after offers'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Call after offers'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1905044636735842 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Complete application'
#
# 1: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Complete application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1905044636735842 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Complete application'
#
# 1: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Complete application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
#
# 1.1905044636735842 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# The following resources are available:
# 0: User_140, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_140' is not allowed to perform the activity 'W_Validate application'
#
# 1: User_146, score: -inf, considering:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	The resource 'User_146' is not allowed to perform the activity 'W_Validate application'
#
# Type the index of the resource to select. Type -1 to not assign any resource.
# Invalid resource, cannot allocate. Skip.
# No assignment made
# (0.31708883105423674,
#  'COMPLETED: you completed 1.1963965367807996 hours of simulated customer cases. 27 cases started. 14 cases run to completion.')

# %% [markdown]
# <font color='#0000DD'><b> Afterward, we can reset the mode and continue the simulation for some more hours.

# %%
planner.mode = Mode.AUTOMATED
simulator.run(2)
# Out:
# 1.2011344077714512 case-10 task-42: W_Call after offers
# Resources Available: {'User_146', 'User_97', 'User_140'}
# Resources in Pool: {'User_97'}
# Assigning: User_97 to task-42 considering the following:
#  	Seniority 'Low' is sufficient for risk class 'Low' of loan goal 'Home improvement'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.2011344077714512 case-7 task-39: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2011344077714512 case-6 task-33: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2011344077714512 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2011344077714512 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2011344077714512 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2011344077714512 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2011344077714512 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2344957967500692 case-4 task-43: W_Call incomplete files
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_146', 'User_85'}
# Assigning: User_85 to task-43 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call incomplete files'
#
#
# 1.2344957967500692 case-7 task-39: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2344957967500692 case-6 task-33: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2344957967500692 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2344957967500692 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2344957967500692 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2344957967500692 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2344957967500692 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2371951258673703 case-7 task-39: W_Call after offers
# Resources Available: {'User_146', 'User_97', 'User_140'}
# Resources in Pool: {'User_97'}
# Assigning: User_97 to task-39 considering the following:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.2371951258673703 case-6 task-33: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2371951258673703 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2371951258673703 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2371951258673703 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2371951258673703 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2371951258673703 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2371951258673703 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2843238529515246 case-6 task-33: W_Complete application
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-33 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 1.2843238529515246 case-12 task-45: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2843238529515246 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2843238529515246 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2843238529515246 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2843238529515246 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2843238529515246 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2843238529515246 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2849533444855485 case-3 task-46: W_Call after offers
# Resources Available: {'User_47', 'User_146', 'User_140'}
# Resources in Pool: {'User_47'}
# Assigning: User_47 to task-46 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Not speficied'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.2849533444855485 case-12 task-45: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2849533444855485 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2849533444855485 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2849533444855485 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2849533444855485 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2849533444855485 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2849533444855485 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2865968414783489 case-12 task-45: W_Call after offers
# Resources Available: {'User_146', 'User_96', 'User_140'}
# Resources in Pool: {'User_96'}
# Assigning: User_96 to task-45 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.2865968414783489 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2865968414783489 case-14 task-47: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2865968414783489 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2865968414783489 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2865968414783489 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2865968414783489 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2865968414783489 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2969600556858445 case-15 task-38: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2969600556858445 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2969600556858445 case-14 task-47: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2969600556858445 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2969600556858445 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2969600556858445 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2969600556858445 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2969600556858445 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2974072002311814 case-15 task-38: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2974072002311814 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2974072002311814 case-14 task-47: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2974072002311814 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2974072002311814 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2974072002311814 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2974072002311814 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2974072002311814 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.2974072002311814 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3087332938789962 case-15 task-38: W_Complete application
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-38 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 1.3087332938789962 case-8 task-25: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3087332938789962 case-14 task-47: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3087332938789962 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3087332938789962 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3087332938789962 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3087332938789962 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3087332938789962 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3087332938789962 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3087332938789962 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3126438512085932 case-8 task-25: W_Complete application
# Resources Available: {'User_99', 'User_146', 'User_140'}
# Resources in Pool: {'User_99'}
# Assigning: User_99 to task-25 considering the following:
#  	Seniority 'High' is sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 1.3126438512085932 case-14 task-47: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3126438512085932 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3126438512085932 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3126438512085932 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3126438512085932 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3126438512085932 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3126438512085932 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3126438512085932 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3247593377657139 case-7 task-51: W_Call after offers
# Resources Available: {'User_146', 'User_97', 'User_140'}
# Resources in Pool: {'User_97'}
# Assigning: User_97 to task-51 considering the following:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.3247593377657139 case-14 task-47: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3247593377657139 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3247593377657139 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3247593377657139 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3247593377657139 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3247593377657139 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3247593377657139 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3247593377657139 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3636648299742953 case-7 task-52: W_Call after offers
# Resources Available: {'User_146', 'User_97', 'User_140'}
# Resources in Pool: {'User_97'}
# Assigning: User_97 to task-52 considering the following:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.3636648299742953 case-14 task-47: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3636648299742953 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3636648299742953 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3636648299742953 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3636648299742953 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3636648299742953 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3636648299742953 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3636648299742953 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.366081056331969 case-14 task-47: W_Call after offers
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-47 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Other, see explanation'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.366081056331969 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.366081056331969 case-6 task-53: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.366081056331969 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.366081056331969 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.366081056331969 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.366081056331969 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.366081056331969 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.366081056331969 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3677139539150305 case-12 task-54: W_Call after offers
# Resources Available: {'User_146', 'User_96', 'User_140'}
# Resources in Pool: {'User_96'}
# Assigning: User_96 to task-54 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.3677139539150305 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3677139539150305 case-6 task-53: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3677139539150305 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3677139539150305 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3677139539150305 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3677139539150305 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3677139539150305 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3677139539150305 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3892826425450935 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_97', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3892826425450935 case-9 task-34: W_Call after offers
# Resources Available: {'User_146', 'User_97', 'User_140'}
# Resources in Pool: {'User_97'}
# Assigning: User_97 to task-34 considering the following:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.3892826425450935 case-6 task-53: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3892826425450935 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3892826425450935 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3892826425450935 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3892826425450935 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3892826425450935 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.3892826425450935 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4142837373739479 case-15 task-56: W_Complete application
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-56 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 1.4142837373739479 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4142837373739479 case-6 task-53: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4142837373739479 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4142837373739479 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4142837373739479 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4142837373739479 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4142837373739479 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4142837373739479 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4205826389093845 case-12 task-57: W_Validate application
# Resources Available: {'User_146', 'User_96', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4205826389093845 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_96', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4205826389093845 case-6 task-53: W_Call after offers
# Resources Available: {'User_146', 'User_96', 'User_140'}
# Resources in Pool: {'User_96'}
# Assigning: User_96 to task-53 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.4205826389093845 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4205826389093845 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4205826389093845 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4205826389093845 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4205826389093845 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4205826389093845 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4567234119777759 case-12 task-57: W_Validate application
# Resources Available: {'User_99', 'User_146', 'User_140'}
# Resources in Pool: {'User_99'}
# Assigning: User_99 to task-57 considering the following:
#  	Seniority 'High' is sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Validate application'
#
#
# 1.4567234119777759 case-8 task-58: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4567234119777759 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4567234119777759 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4567234119777759 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4567234119777759 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4567234119777759 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4567234119777759 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4567234119777759 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4644205642470227 case-14 task-59: W_Call after offers
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-59 considering the following:
#  	Seniority 'Medium' is sufficient for risk class 'Low' of loan goal 'Other, see explanation'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.4644205642470227 case-8 task-58: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4644205642470227 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4644205642470227 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4644205642470227 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4644205642470227 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4644205642470227 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4644205642470227 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4644205642470227 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4772177672122855 case-8 task-58: W_Call after offers
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-58 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.4772177672122855 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4772177672122855 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4772177672122855 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4772177672122855 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4772177672122855 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4772177672122855 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4772177672122855 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4965924919197122 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_97', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4965924919197122 case-16 task-48: W_Complete application
# Resources Available: {'User_146', 'User_97', 'User_140'}
# Resources in Pool: {'User_97'}
# Assigning: User_97 to task-48 considering the following:
#  	Seniority 'Low' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 1.4965924919197122 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4965924919197122 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4965924919197122 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4965924919197122 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.4965924919197122 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5006392346598842 case-15 task-60: W_Call after offers
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-60 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Call after offers'
#
#
# 1.5006392346598842 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5006392346598842 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5006392346598842 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5006392346598842 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5006392346598842 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5006392346598842 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5344660621780195 case-6 task-61: W_Validate application
# Resources Available: {'User_146', 'User_96', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5344660621780195 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_96', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5344660621780195 case-11 task-41: W_Complete application
# Resources Available: {'User_146', 'User_96', 'User_140'}
# Resources in Pool: {'User_96'}
# Assigning: User_96 to task-41 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Complete application'
#
#
# 1.5344660621780195 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5344660621780195 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5344660621780195 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5344660621780195 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5536013201277081 case-6 task-61: W_Validate application
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70'}
# Assigning: User_70 to task-61 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Validate application'
#
#
# 1.5536013201277081 case-2 task-40: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5536013201277081 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5536013201277081 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5536013201277081 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5536013201277081 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5619945499125731 case-2 task-40: W_Validate application
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-40 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource has relevant role(s) for activity 'W_Validate application'
#
#
# 1.5619945499125731 case-15 task-62: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5619945499125731 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5619945499125731 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5619945499125731 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5619945499125731 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5620274656587798 case-12 task-63: W_Call incomplete files
# Resources Available: {'User_99', 'User_146', 'User_140'}
# Resources in Pool: {'User_99', 'User_146'}
# Assigning: User_99 to task-63 considering the following:
#  	Seniority 'High' is sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Call incomplete files'
#
#
# 1.5620274656587798 case-15 task-62: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5620274656587798 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5620274656587798 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5620274656587798 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5620274656587798 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5930678895507155 case-6 task-64: W_Call incomplete files
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70', 'User_146'}
# Assigning: User_70 to task-64 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Call incomplete files'
#
#
# 1.5930678895507155 case-15 task-62: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5930678895507155 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5930678895507155 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5930678895507155 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.5930678895507155 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6119915373150224 case-12 task-65: W_Call incomplete files
# Resources Available: {'User_99', 'User_146', 'User_140'}
# Resources in Pool: {'User_99', 'User_146'}
# Assigning: User_99 to task-65 considering the following:
#  	Seniority 'High' is sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Call incomplete files'
#
#
# 1.6119915373150224 case-15 task-62: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6119915373150224 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6119915373150224 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6119915373150224 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6119915373150224 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6168034027480322 case-15 task-62: W_Validate application
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Assigning: User_85 to task-62 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Validate application'
#
#
# 1.6168034027480322 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6168034027480322 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6168034027480322 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6168034027480322 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6439530325645444 case-6 task-66: W_Call incomplete files
# Resources Available: {'User_70', 'User_146', 'User_140'}
# Resources in Pool: {'User_70', 'User_146'}
# Assigning: User_70 to task-66 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Car'
# 	Resource is an expert on 'ApplicationType' 'New credit'
# 	Resource has relevant role(s) for activity 'W_Call incomplete files'
#
#
# 1.6439530325645444 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6439530325645444 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6439530325645444 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6439530325645444 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6547107784795245 case-15 task-67: W_Assess potential fraud
# Resources Available: {'User_85', 'User_146', 'User_140'}
# Resources in Pool: {'User_85'}
# Interrupt
# Pausing Simulation at time 1.6547107784795245. Will complete running current cycle. Interrupt again for immediate cancellation.
# Assigning: User_85 to task-67 considering the following:
#  	Seniority 'Medium' not sufficient for risk class 'High' of loan goal 'Existing loan takeover'
# 	Resource has relevant role(s) for activity 'W_Assess potential fraud'
#
#
# 1.6547107784795245 case-10 task-44: W_Call after offers
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6547107784795245 case-4 task-50: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6547107784795245 case-13 task-32: W_Complete application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
#
# 1.6547107784795245 case-7 task-55: W_Validate application
# Resources Available: {'User_146', 'User_140'}
# Resources in Pool: set()
# No assignment made
# (0.8182073688212546,
#  'COMPLETED: you completed 3.201134407771451 hours of simulated customer cases. 42 cases started. 32 cases run to completion.')

# %% [markdown]
# <font color='#0000DD'><b> Finally, we can have a look at the whole final graph, stretching over a lot of resources and tasks.

# %%
draw_graph(planner.graph)
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))
